# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt

from terrain import DiscreteTerrain
from prospect import UniformProspect, EGreedyProspect, SoftmaxProspect, UCB1Prospect
from vizualizer import Vizualizer

# %%
plt.style.use('ggplot')

# %%
terrain = DiscreteTerrain(10, 10)

# %%
np.max(terrain.grid)
# Out:
# 0.9970099882743325

# %% [markdown]
# ### Uniform

# %%
prospect = UniformProspect(trials=1000, terrain=terrain)
prospect.prospect()
viz = Vizualizer(prospect.knowledge)
viz.graph_2D(prospect)
plt.grid()
plt.show()
# Out:
# UniformProspect: 100%|██████████| 1000/1000 [00:00<00:00, 3363.08it/s]

# %% [markdown]
# ### Epsilon-Greedy

# %%
prospect = EGreedyProspect(trials=1000, terrain=terrain)
prospect.prospect()
viz = Vizualizer(prospect.knowledge)
viz.graph_2D(prospect)
plt.grid()
plt.show()
# Out:
# EGreedyProspect: 100%|██████████| 1000/1000 [00:00<00:00, 2247.57it/s]

# %% [markdown]
# ### Softmax

# %%
prospect = SoftmaxProspect(trials=1000, terrain=terrain)
prospect.prospect()
viz = Vizualizer(prospect.knowledge)
viz.graph_2D(prospect)
plt.grid()
plt.show()
# Out:
# SoftmaxProspect: 100%|██████████| 1000/1000 [00:00<00:00, 1487.83it/s]

# %% [markdown]
# ### UCB1

# %%
prospect = UCB1Prospect(trials=1000, terrain=terrain)
prospect.prospect()
viz = Vizualizer(prospect.knowledge)
viz.graph_2D(prospect)
plt.grid()
plt.show()
# Out:
# UCB1Prospect: 100%|██████████| 1000/1000 [00:00<00:00, 1384.36it/s]

# %%
for prospect_class in [UniformProspect, EGreedyProspect, SoftmaxProspect, UCB1Prospect]:
    prospect = prospect_class(trials=1000, terrain=terrain)
    prospect.prospect()
    viz = Vizualizer(prospect.knowledge)
    viz.graph_2D(prospect)
plt.legend(['UniformProspect', 'EGreedyProspect', 'SoftmaxProspect', 'UCB1Prospect'])
plt.show()

# %% [markdown]
# ### All

# %%
for prospect_class in [UniformProspect, EGreedyProspect, SoftmaxProspect, UCB1Prospect]:
    prospect = prospect_class(trials=1000, terrain=terrain)
    prospect.prospect()
    viz = Vizualizer(prospect.knowledge)
    viz.graph_2D(prospect)
plt.legend(['UniformProspect', 'EGreedyProspect', 'SoftmaxProspect', 'UCB1Prospect'])
plt.show()

# %%
for prospect_class in [UniformProspect, EGreedyProspect, SoftmaxProspect, UCB1Prospect]:
    prospect = prospect_class(trials=10000, terrain=terrain)
    prospect.prospect()
    viz = Vizualizer(prospect.knowledge)
    viz.graph_2D(prospect)
plt.legend(['UniformProspect', 'EGreedyProspect', 'SoftmaxProspect', 'UCB1Prospect'])
plt.show()
# Out:
# UniformProspect: 100%|██████████| 10000/10000 [00:10<00:00, 935.13it/s]
# EGreedyProspect: 100%|██████████| 10000/10000 [00:32<00:00, 307.81it/s]
# SoftmaxProspect: 100%|██████████| 10000/10000 [00:39<00:00, 255.87it/s]
# UCB1Prospect: 100%|██████████| 10000/10000 [00:38<00:00, 259.09it/s]
