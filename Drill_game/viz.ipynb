# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

from terrain import DiscreteTerrain
from prospect import UniformProspect, EGreedyProspect, SoftmaxProspect, UCB1Prospect
from vizualizer import Vizualizer

# %%
terrain = DiscreteTerrain(10, 10)

# %%
np.max(terrain.grid)
# Out:
# 0.9970099882743325

# %%
prospect = UniformProspect(trials=1000, terrain=terrain)
prospect.prospect()
viz = Vizualizer(prospect.knowledge)
viz.graph_2D(prospect)

# %%
prospect = EGreedyProspect(trials=1000, terrain=terrain)
prospect.prospect()
viz = Vizualizer(prospect.knowledge)
viz.graph_2D(prospect)

# %%
prospect = SoftmaxProspect(trials=1000, terrain=terrain)
prospect.prospect()
viz = Vizualizer(prospect.knowledge)
viz.graph_2D(prospect)

# %%
prospect = UCB1Prospect(trials=1000, terrain=terrain)
prospect.prospect()
viz = Vizualizer(prospect.knowledge)
viz.graph_2D(prospect)
# Out:
# /home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py:77: RuntimeWarning: divide by zero encountered in log
#   probs = self.knowledge + np.sqrt(2 * np.log(n) / self.trials_count)
# /home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py:77: RuntimeWarning: invalid value encountered in sqrt
#   probs = self.knowledge + np.sqrt(2 * np.log(n) / self.trials_count)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/sylvanbrocard/Documents/Drill_game/Drill_game/viz.ipynb Cell 8' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/sylvanbrocard/Documents/Drill_game/Drill_game/viz.ipynb#ch0000008?line=0'>1</a> prospect = UCB1Prospect(trials=1000, terrain=terrain)
# ----> <a href='vscode-notebook-cell:/home/sylvanbrocard/Documents/Drill_game/Drill_game/viz.ipynb#ch0000008?line=1'>2</a> prospect.prospect()
#       <a href='vscode-notebook-cell:/home/sylvanbrocard/Documents/Drill_game/Drill_game/viz.ipynb#ch0000008?line=2'>3</a> viz = Vizualizer(prospect.knowledge)
#       <a href='vscode-notebook-cell:/home/sylvanbrocard/Documents/Drill_game/Drill_game/viz.ipynb#ch0000008?line=3'>4</a> viz.graph_2D(prospect)
#
# File ~/Documents/Drill_game/Drill_game/prospect.py:28, in Prospect.prospect(self)
#      <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=25'>26</a> def prospect(self) -> None:
#      <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=26'>27</a>     for _ in range(self.trials):
# ---> <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=27'>28</a>         self.prospect_once()
#
# File ~/Documents/Drill_game/Drill_game/prospect.py:69, in UCB1Prospect.prospect_once(self)
#      <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=67'>68</a> def prospect_once(self) -> None:
# ---> <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=68'>69</a>     x, y = self.decide_next_coordinates()
#      <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=69'>70</a>     self.rewards.append(((x,y),self.terrain.get_reward(x,y)))
#      <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=70'>71</a>     tile_draws = [reward for loc, reward in self.rewards if loc == (x,y)]
#
# File ~/Documents/Drill_game/Drill_game/prospect.py:78, in UCB1Prospect.decide_next_coordinates(self)
#      <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=75'>76</a> n = len(self.rewards)
#      <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=76'>77</a> probs = self.knowledge + np.sqrt(2 * np.log(n) / self.trials_count)
# ---> <a href='file:///home/sylvanbrocard/Documents/Drill_game/Drill_game/prospect.py?line=77'>78</a> return self.rng.choice(np.transpose(np.nonzero(probs == np.max(probs))))
#
# File _generator.pyx:719, in numpy.random._generator.Generator.choice()
#
# ValueError: a cannot be empty unless no samples are taken
